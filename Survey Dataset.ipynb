# %% [markdown]
# Link to Dataset : https://drive.google.com/file/d/15BGMfzCj_010sx4rbvMyrspYCtyc8y-w/view

# %%
import pandas as pd

# %%
survey = pd.read_csv('Survey Dataset.csv')

# %%
survey.head()
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3       5-24-2017       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4       5-24-2017       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 4            5       5-24-2017       Rural   Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction age gender  \
# 0      BJP           BJP  Fully Dissatisfied  Fully Dissatisfied  26   Male
# 1     RLSP         JD(U)  Somewhat Satisfied  Fully Dissatisfied  34   Male
# 2   JAP(L)           BJP  Fully Dissatisfied  Somewhat Satisfied  25   Male
# 3      RJD           RJD  Fully Dissatisfied  Somewhat Satisfied  36   Male
# 4    JD(U)  Did not vote     Fully Satisfied     Fully Satisfied  22   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419
# 2          191      Gen  0.673762
# 3          194      Gen  1.101298
# 4          176       BC  0.333505

# %%
survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6867 entries, 0 to 6866
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   response_id       6867 non-null   int64
#  1   collection_date   6867 non-null   object
#  2   urban_rural       6867 non-null   object
#  3   education         6867 non-null   object
#  4   income            6867 non-null   object
#  5   Vote_Now          6867 non-null   object
#  6   Past_Vote         6867 non-null   object
#  7   CM_satisfaction   6867 non-null   object
#  8   MLA_satisfaction  6867 non-null   object
#  9   age               6867 non-null   object
#  10  gender            6867 non-null   object
#  11  assembly_no       6867 non-null   int64
#  12  category          6867 non-null   object
#  13  weight            6867 non-null   float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 751.2+ KB

# %%
survey.shape
# Out:
# (6867, 14)

# %%
survey.isnull().sum()
# Out:
# response_id         0
# collection_date     0
# urban_rural         0
# education           0
# income              0
# Vote_Now            0
# Past_Vote           0
# CM_satisfaction     0
# MLA_satisfaction    0
# age                 0
# gender              0
# assembly_no         0
# category            0
# weight              0
# dtype: int64

# %% [markdown]
# # Question 1 - Load the dataset into a pandas dataframe. Name the variable as “survey”.

# %%
survey
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# 0     ₹ 30,000 - ₹ 50,000      BJP           BJP  Fully Dissatisfied
# 1     ₹ 20,000 - ₹ 30,000     RLSP         JD(U)  Somewhat Satisfied
# 2      ₹ 5,000 - ₹ 10,000   JAP(L)           BJP  Fully Dissatisfied
# 3     ₹ 10,000 - ₹ 20,000      RJD           RJD  Fully Dissatisfied
# 4     ₹ 50,000 - ₹ 80,000    JD(U)  Did not vote     Fully Satisfied
# ...                   ...      ...           ...                 ...
# 6862    BPL/Below ₹ 5,000    JD(U)           BJP     Fully Satisfied
# 6863    BPL/Below ₹ 5,000      RJD           RJD  Fully Dissatisfied
# 6864   ₹ 5,000 - ₹ 10,000   JAP(L)           RJD           Can’t say
# 6865  ₹ 10,000 - ₹ 20,000      BJP  Did not vote     Fully Satisfied
# 6866   ₹ 5,000 - ₹ 10,000   JAP(L)        JAP(L)     Fully Satisfied
#
#         MLA_satisfaction age gender  assembly_no category    weight
# 0     Fully Dissatisfied  26   Male          211      Gen  0.346969
# 1     Fully Dissatisfied  34   Male          189       BC  0.603419
# 2     Somewhat Satisfied  25   Male          191      Gen  0.673762
# 3     Somewhat Satisfied  36   Male          194      Gen  1.101298
# 4        Fully Satisfied  22   Male          176       BC  0.333505
# ...                  ...  ..    ...          ...      ...       ...
# 6862  Fully Dissatisfied  25   Male          166      Gen  0.036329
# 6863  Fully Dissatisfied  30   Male          169       BC  0.252780
# 6864  Fully Dissatisfied  20   Male          241      Gen  1.812926
# 6865  Somewhat Satisfied  23   Male          243      Gen  0.080137
# 6866     Fully Satisfied  33   Male          241      Gen  1.797518
#
# [6867 rows x 14 columns]

# %% [markdown]
# # Question 2 - How many samples were collected on each day?

# %%
survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6867 entries, 0 to 6866
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   response_id       6867 non-null   int64
#  1   collection_date   6867 non-null   object
#  2   urban_rural       6867 non-null   object
#  3   education         6867 non-null   object
#  4   income            6867 non-null   object
#  5   Vote_Now          6867 non-null   object
#  6   Past_Vote         6867 non-null   object
#  7   CM_satisfaction   6867 non-null   object
#  8   MLA_satisfaction  6867 non-null   object
#  9   age               6867 non-null   object
#  10  gender            6867 non-null   object
#  11  assembly_no       6867 non-null   int64
#  12  category          6867 non-null   object
#  13  weight            6867 non-null   float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 751.2+ KB

# %%
survey['collection_date'] = pd.to_datetime(survey['collection_date'])

# %%
survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6867 entries, 0 to 6866
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   response_id       6867 non-null   int64
#  1   collection_date   6867 non-null   datetime64[ns]
#  2   urban_rural       6867 non-null   object
#  3   education         6867 non-null   object
#  4   income            6867 non-null   object
#  5   Vote_Now          6867 non-null   object
#  6   Past_Vote         6867 non-null   object
#  7   CM_satisfaction   6867 non-null   object
#  8   MLA_satisfaction  6867 non-null   object
#  9   age               6867 non-null   object
#  10  gender            6867 non-null   object
#  11  assembly_no       6867 non-null   int64
#  12  category          6867 non-null   object
#  13  weight            6867 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(10)
# memory usage: 751.2+ KB

# %%
survey.head()
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1      2017-05-24       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2      2017-05-24       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3      2017-05-24       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4      2017-05-24       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 4            5      2017-05-24       Rural   Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction age gender  \
# 0      BJP           BJP  Fully Dissatisfied  Fully Dissatisfied  26   Male
# 1     RLSP         JD(U)  Somewhat Satisfied  Fully Dissatisfied  34   Male
# 2   JAP(L)           BJP  Fully Dissatisfied  Somewhat Satisfied  25   Male
# 3      RJD           RJD  Fully Dissatisfied  Somewhat Satisfied  36   Male
# 4    JD(U)  Did not vote     Fully Satisfied     Fully Satisfied  22   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419
# 2          191      Gen  0.673762
# 3          194      Gen  1.101298
# 4          176       BC  0.333505

# %%
survey['collection_date'].value_counts()
# Out:
# 2017-05-24    1479
# 2017-05-25     998
# 2017-05-28     761
# 2017-05-27     665
# 2017-05-29     620
# 2017-06-01     607
# 2017-05-26     598
# 2017-05-30     582
# 2017-05-31     557
# Name: collection_date, dtype: int64

# %% [markdown]
# # Question 3 - What proportion of the total respondents were aged less than 45?

# %%
survey.head()
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1      2017-05-24       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2      2017-05-24       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3      2017-05-24       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4      2017-05-24       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 4            5      2017-05-24       Rural   Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction age gender  \
# 0      BJP           BJP  Fully Dissatisfied  Fully Dissatisfied  26   Male
# 1     RLSP         JD(U)  Somewhat Satisfied  Fully Dissatisfied  34   Male
# 2   JAP(L)           BJP  Fully Dissatisfied  Somewhat Satisfied  25   Male
# 3      RJD           RJD  Fully Dissatisfied  Somewhat Satisfied  36   Male
# 4    JD(U)  Did not vote     Fully Satisfied     Fully Satisfied  22   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419
# 2          191      Gen  0.673762
# 3          194      Gen  1.101298
# 4          176       BC  0.333505

# %%
survey['age'].unique()
# Out:
# array(['26', '34', '25', '36', '22', '38', '23', '42', '51', '29', '24',
#        '30', '39', '37', '19', '44', '53', '32', '21', '18', '20', '27',
#        '48', '28', '45', '74', '35', '31', '70', '40', '49', '46', '43',
#        '41', '33', '58', '24ko', '56', '50', '55', '54', '62', '60', '59',
#        '47', '61', '52', '66', '57', '67', '65', '71', '63', '64', '68',
#        '69', '99', '72', '75', '76'], dtype=object)

# %%
survey[survey['age'] == '24ko']
# Out:
#      response_id collection_date urban_rural          education  \
# 123          124      2017-05-24       Rural  Post - Graduation
#
#                 income Vote_Now Past_Vote  CM_satisfaction  \
# 123  BPL/Below ₹ 5,000    JD(U)    Others  Fully Satisfied
#
#           MLA_satisfaction   age gender  assembly_no category    weight
# 123  Somewhat Dissatisfied  24ko   Male          180      Gen  2.092567

# %% [markdown]
# We need to replace '24ko' with 24 using replace command

# %%
survey['age'].replace({'24ko':24}, inplace = True)

# %%
survey['age'].unique()
# Out:
# array(['26', '34', '25', '36', '22', '38', '23', '42', '51', '29', '24',
#        '30', '39', '37', '19', '44', '53', '32', '21', '18', '20', '27',
#        '48', '28', '45', '74', '35', '31', '70', '40', '49', '46', '43',
#        '41', '33', '58', 24, '56', '50', '55', '54', '62', '60', '59',
#        '47', '61', '52', '66', '57', '67', '65', '71', '63', '64', '68',
#        '69', '99', '72', '75', '76'], dtype=object)

# %%
survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6867 entries, 0 to 6866
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   response_id       6867 non-null   int64
#  1   collection_date   6867 non-null   datetime64[ns]
#  2   urban_rural       6867 non-null   object
#  3   education         6867 non-null   object
#  4   income            6867 non-null   object
#  5   Vote_Now          6867 non-null   object
#  6   Past_Vote         6867 non-null   object
#  7   CM_satisfaction   6867 non-null   object
#  8   MLA_satisfaction  6867 non-null   object
#  9   age               6867 non-null   object
#  10  gender            6867 non-null   object
#  11  assembly_no       6867 non-null   int64
#  12  category          6867 non-null   object
#  13  weight            6867 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(10)
# memory usage: 751.2+ KB

# %%
survey['age'] = survey['age'].astype(int)

# %%
survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6867 entries, 0 to 6866
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   response_id       6867 non-null   int64
#  1   collection_date   6867 non-null   datetime64[ns]
#  2   urban_rural       6867 non-null   object
#  3   education         6867 non-null   object
#  4   income            6867 non-null   object
#  5   Vote_Now          6867 non-null   object
#  6   Past_Vote         6867 non-null   object
#  7   CM_satisfaction   6867 non-null   object
#  8   MLA_satisfaction  6867 non-null   object
#  9   age               6867 non-null   int64
#  10  gender            6867 non-null   object
#  11  assembly_no       6867 non-null   int64
#  12  category          6867 non-null   object
#  13  weight            6867 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(9)
# memory usage: 751.2+ KB

# %% [markdown]
# What proportion of the total respondents were aged less than 45?

# %%
a = len(survey['age'])

# %%
b = len(survey[survey['age'] < 45])

# %%
b/a
# Out:
# 0.9318479685452162

# %% [markdown]
# # Question 4 - Create a new column in the dataframe “age_group”. This column should contain the age group the respondent belongs to. The age groups are 18-25, 25-40, 40-55 and 55+. The dataframe should look like this after the column creation.

# %%
survey.head()
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1      2017-05-24       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2      2017-05-24       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3      2017-05-24       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4      2017-05-24       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 4            5      2017-05-24       Rural   Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP           BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
# 1     RLSP         JD(U)  Somewhat Satisfied  Fully Dissatisfied   34   Male
# 2   JAP(L)           BJP  Fully Dissatisfied  Somewhat Satisfied   25   Male
# 3      RJD           RJD  Fully Dissatisfied  Somewhat Satisfied   36   Male
# 4    JD(U)  Did not vote     Fully Satisfied     Fully Satisfied   22   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419
# 2          191      Gen  0.673762
# 3          194      Gen  1.101298
# 4          176       BC  0.333505

# %%
def group(item):
    if item >= 18 and item < 25:
        return '18-25'
    elif item >= 25 and item < 40:
        return '25-40'
    elif item >= 40 and item < 55:
        return '40-55'
    else:
        return '55+'

# %%
group(35)
# Out:
# '25-40'

# %%
age_group = survey['age'].apply(group)

# %%
age_group
# Out:
# 0       25-40
# 1       25-40
# 2       25-40
# 3       25-40
# 4       18-25
#         ...
# 6862    25-40
# 6863    25-40
# 6864    18-25
# 6865    18-25
# 6866    25-40
# Name: age, Length: 6867, dtype: object

# %%
survey.insert(10, 'age_group' , age_group)

# %%
survey.head(15)
# Out:
#     response_id collection_date urban_rural               education  \
# 0             1      2017-05-24       Rural               12th Pass
# 1             2      2017-05-24       Rural                Graduate
# 2             3      2017-05-24       Rural                Graduate
# 3             4      2017-05-24       Urban                Graduate
# 4             5      2017-05-24       Rural                Graduate
# 5             6      2017-05-24       Urban                Graduate
# 6             7      2017-05-24       Urban                Graduate
# 7             8      2017-05-24       Rural  Professional Education
# 8             9      2017-05-24       Urban               12th Pass
# 9            10      2017-05-24       Urban               12th Pass
# 10           11      2017-05-24       Urban               12th Pass
# 11           12      2017-05-24       Urban                Graduate
# 12           13      2017-05-24       Urban       Post - Graduation
# 13           14      2017-05-24       Urban                Graduate
# 14           15      2017-05-24       Rural                Graduate
#
#                  income   Vote_Now     Past_Vote        CM_satisfaction  \
# 0   ₹ 30,000 - ₹ 50,000        BJP           BJP     Fully Dissatisfied
# 1   ₹ 20,000 - ₹ 30,000       RLSP         JD(U)     Somewhat Satisfied
# 2    ₹ 5,000 - ₹ 10,000     JAP(L)           BJP     Fully Dissatisfied
# 3   ₹ 10,000 - ₹ 20,000        RJD           RJD     Fully Dissatisfied
# 4   ₹ 50,000 - ₹ 80,000      JD(U)  Did not vote        Fully Satisfied
# 5   ₹ 20,000 - ₹ 30,000     Others           BJP     Somewhat Satisfied
# 6     BPL/Below ₹ 5,000        RJD           BJP     Fully Dissatisfied
# 7    ₹ 1,50,000 & above        BJP         JD(U)  Somewhat Dissatisfied
# 8     BPL/Below ₹ 5,000        BJP           BJP        Fully Satisfied
# 9   ₹ 20,000 - ₹ 30,000        RJD           RJD     Fully Dissatisfied
# 10   ₹ 5,000 - ₹ 10,000        BJP           BJP     Somewhat Satisfied
# 11  ₹ 10,000 - ₹ 20,000        LJP         JD(U)     Somewhat Satisfied
# 12   ₹ 5,000 - ₹ 10,000  Undecided         JD(U)  Somewhat Dissatisfied
# 13  ₹ 10,000 - ₹ 20,000      JD(U)           BJP     Somewhat Satisfied
# 14   ₹ 1,50,000 & above        BJP           BJP        Fully Satisfied
#
#          MLA_satisfaction  age age_group gender  assembly_no category  \
# 0      Fully Dissatisfied   26     25-40   Male          211      Gen
# 1      Fully Dissatisfied   34     25-40   Male          189       BC
# 2      Somewhat Satisfied   25     25-40   Male          191      Gen
# 3      Somewhat Satisfied   36     25-40   Male          194      Gen
# 4         Fully Satisfied   22     18-25   Male          176       BC
# 5      Fully Dissatisfied   38     25-40   Male          178      Gen
# 6      Fully Dissatisfied   34     25-40   Male          172       BC
# 7   Somewhat Dissatisfied   34     25-40   Male          186       ST
# 8      Fully Dissatisfied   23     18-25   Male          181      Gen
# 9      Fully Dissatisfied   26     25-40   Male          181       BC
# 10  Somewhat Dissatisfied   38     25-40   Male          181      EBC
# 11     Fully Dissatisfied   42     40-55   Male          183       BC
# 12  Somewhat Dissatisfied   51     40-55   Male          183       SC
# 13     Fully Dissatisfied   29     25-40   Male          184      Gen
# 14     Fully Dissatisfied   24     18-25   Male          199      Gen
#
#        weight
# 0    0.346969
# 1    0.603419
# 2    0.673762
# 3    1.101298
# 4    0.333505
# 5    0.382603
# 6    0.521283
# 7    0.340652
# 8    0.226477
# 9    0.713059
# 10   3.850583
# 11   2.824391
# 12  20.558759
# 13   0.275509
# 14   0.226477

# %% [markdown]
# # Question 5 - How many samples were collected for each age-group? Which age-group had the most samples?

# %%
survey.head()
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1      2017-05-24       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2      2017-05-24       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3      2017-05-24       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4      2017-05-24       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 4            5      2017-05-24       Rural   Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction  age  \
# 0      BJP           BJP  Fully Dissatisfied  Fully Dissatisfied   26
# 1     RLSP         JD(U)  Somewhat Satisfied  Fully Dissatisfied   34
# 2   JAP(L)           BJP  Fully Dissatisfied  Somewhat Satisfied   25
# 3      RJD           RJD  Fully Dissatisfied  Somewhat Satisfied   36
# 4    JD(U)  Did not vote     Fully Satisfied     Fully Satisfied   22
#
#   age_group gender  assembly_no category    weight
# 0     25-40   Male          211      Gen  0.346969
# 1     25-40   Male          189       BC  0.603419
# 2     25-40   Male          191      Gen  0.673762
# 3     25-40   Male          194      Gen  1.101298
# 4     18-25   Male          176       BC  0.333505

# %%
survey['age_group'].value_counts().reset_index()
# Out:
#    index  age_group
# 0  25-40       3844
# 1  18-25       2094
# 2  40-55        801
# 3    55+        128

# %% [markdown]
# # Question 6 - What proportion of the respondents had opted for the RJD party in both the Vote_Now and the Past_Vote questions?

# %%
survey.head()
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1      2017-05-24       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2      2017-05-24       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3      2017-05-24       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4      2017-05-24       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 4            5      2017-05-24       Rural   Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction  age  \
# 0      BJP           BJP  Fully Dissatisfied  Fully Dissatisfied   26
# 1     RLSP         JD(U)  Somewhat Satisfied  Fully Dissatisfied   34
# 2   JAP(L)           BJP  Fully Dissatisfied  Somewhat Satisfied   25
# 3      RJD           RJD  Fully Dissatisfied  Somewhat Satisfied   36
# 4    JD(U)  Did not vote     Fully Satisfied     Fully Satisfied   22
#
#   age_group gender  assembly_no category    weight
# 0     25-40   Male          211      Gen  0.346969
# 1     25-40   Male          189       BC  0.603419
# 2     25-40   Male          191      Gen  0.673762
# 3     25-40   Male          194      Gen  1.101298
# 4     18-25   Male          176       BC  0.333505

# %%
survey[ ( survey['Vote_Now'] == 'RJD' ) & ( survey['Past_Vote'] == 'RJD' )]
# Out:
#       response_id collection_date urban_rural          education  \
# 3               4      2017-05-24       Urban           Graduate
# 9              10      2017-05-24       Urban          12th Pass
# 16             17      2017-05-24       Rural  Post - Graduation
# 19             20      2017-05-24       Rural           Graduate
# 21             22      2017-05-24       Rural           Graduate
# ...           ...             ...         ...                ...
# 6846         6847      2017-06-01       Rural  Post - Graduation
# 6848         6849      2017-06-01       Rural  Post - Graduation
# 6858         6859      2017-06-01       Rural           Graduate
# 6860         6861      2017-06-01       Rural           Graduate
# 6863         6864      2017-06-01       Rural           Graduate
#
#                    income Vote_Now Past_Vote     CM_satisfaction  \
# 3     ₹ 10,000 - ₹ 20,000      RJD       RJD  Fully Dissatisfied
# 9     ₹ 20,000 - ₹ 30,000      RJD       RJD  Fully Dissatisfied
# 16      BPL/Below ₹ 5,000      RJD       RJD  Fully Dissatisfied
# 19    ₹ 20,000 - ₹ 30,000      RJD       RJD  Fully Dissatisfied
# 21     ₹ 5,000 - ₹ 10,000      RJD       RJD  Fully Dissatisfied
# ...                   ...      ...       ...                 ...
# 6846    BPL/Below ₹ 5,000      RJD       RJD  Fully Dissatisfied
# 6848  ₹ 30,000 - ₹ 50,000      RJD       RJD  Fully Dissatisfied
# 6858  ₹ 10,000 - ₹ 20,000      RJD       RJD  Fully Dissatisfied
# 6860    BPL/Below ₹ 5,000      RJD       RJD  Fully Dissatisfied
# 6863    BPL/Below ₹ 5,000      RJD       RJD  Fully Dissatisfied
#
#         MLA_satisfaction  age age_group gender  assembly_no category    weight
# 3     Somewhat Satisfied   36     25-40   Male          194      Gen  1.101298
# 9     Fully Dissatisfied   26     25-40   Male          181       BC  0.713059
# 16    Somewhat Satisfied   24     18-25   Male          194       BC  0.769738
# 19    Fully Dissatisfied   37     25-40   Male          200       BC  0.936383
# 21    Fully Dissatisfied   29     25-40   Male          210       BC  0.713059
# ...                  ...  ...       ...    ...          ...      ...       ...
# 6846  Fully Dissatisfied   31     25-40   Male          151       BC  0.483757
# 6848           Can’t say   27     25-40   Male          143       BC  0.200389
# 6858     Fully Satisfied   24     18-25   Male          241      Gen  1.812926
# 6860     Fully Satisfied   25     25-40   Male          145       BC  0.528469
# 6863  Fully Dissatisfied   30     25-40   Male          169       BC  0.252780
#
# [811 rows x 15 columns]

# %%
a = len(survey[ ( survey['Vote_Now'] == 'RJD' ) & ( survey['Past_Vote'] == 'RJD' )])

# %%
b = len(survey)

# %%
a/b
# Out:
# 0.1181010630551915

# %% [markdown]
# # Question 7 - For each day of sample collection, determine the proportion of respondents who were fully satisfied with the performance of the CM. So if there were a total of 1000 samples on day 1 and 300 out of those said they were fully satisfied, then our answer for that day would be 0.3.

# %%
survey.head()
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1      2017-05-24       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2      2017-05-24       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3      2017-05-24       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4      2017-05-24       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 4            5      2017-05-24       Rural   Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction  age  \
# 0      BJP           BJP  Fully Dissatisfied  Fully Dissatisfied   26
# 1     RLSP         JD(U)  Somewhat Satisfied  Fully Dissatisfied   34
# 2   JAP(L)           BJP  Fully Dissatisfied  Somewhat Satisfied   25
# 3      RJD           RJD  Fully Dissatisfied  Somewhat Satisfied   36
# 4    JD(U)  Did not vote     Fully Satisfied     Fully Satisfied   22
#
#   age_group gender  assembly_no category    weight
# 0     25-40   Male          211      Gen  0.346969
# 1     25-40   Male          189       BC  0.603419
# 2     25-40   Male          191      Gen  0.673762
# 3     25-40   Male          194      Gen  1.101298
# 4     18-25   Male          176       BC  0.333505

# %%
col1 = survey['collection_date'].value_counts()

# %%
col1
# Out:
# 2017-05-24    1479
# 2017-05-25     998
# 2017-05-28     761
# 2017-05-27     665
# 2017-05-29     620
# 2017-06-01     607
# 2017-05-26     598
# 2017-05-30     582
# 2017-05-31     557
# Name: collection_date, dtype: int64

# %%
col2 = survey[survey['CM_satisfaction'] == 'Fully Satisfied']['collection_date'].value_counts()

# %%
col2
# Out:
# 2017-05-24    146
# 2017-05-25     95
# 2017-05-28     92
# 2017-06-01     75
# 2017-05-29     73
# 2017-05-30     65
# 2017-05-31     62
# 2017-05-26     59
# 2017-05-27     54
# Name: collection_date, dtype: int64

# %%
dfnew = pd.DataFrame({'Total' : col1, 'CM_Satisfied': col2})

# %%
dfnew
# Out:
#             Total  CM_Satisfied
# 2017-05-24   1479           146
# 2017-05-25    998            95
# 2017-05-26    598            59
# 2017-05-27    665            54
# 2017-05-28    761            92
# 2017-05-29    620            73
# 2017-05-30    582            65
# 2017-05-31    557            62
# 2017-06-01    607            75

# %%
dfnew['Proportion'] = dfnew['CM_Satisfied']/dfnew['Total']

# %%
dfnew
# Out:
#             Total  CM_Satisfied  Proportion
# 2017-05-24   1479           146    0.098715
# 2017-05-25    998            95    0.095190
# 2017-05-26    598            59    0.098662
# 2017-05-27    665            54    0.081203
# 2017-05-28    761            92    0.120894
# 2017-05-29    620            73    0.117742
# 2017-05-30    582            65    0.111684
# 2017-05-31    557            62    0.111311
# 2017-06-01    607            75    0.123558

# %% [markdown]
# # Question 8 - In a similar fashion create a day-wise proportion of respondents that opted fully dissatisfied with their MLA. Create a line plot of the result with date on x-axis and proportions on the y-axis.

# %%
survey.head()
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1      2017-05-24       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2      2017-05-24       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3      2017-05-24       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4      2017-05-24       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 4            5      2017-05-24       Rural   Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction  age  \
# 0      BJP           BJP  Fully Dissatisfied  Fully Dissatisfied   26
# 1     RLSP         JD(U)  Somewhat Satisfied  Fully Dissatisfied   34
# 2   JAP(L)           BJP  Fully Dissatisfied  Somewhat Satisfied   25
# 3      RJD           RJD  Fully Dissatisfied  Somewhat Satisfied   36
# 4    JD(U)  Did not vote     Fully Satisfied     Fully Satisfied   22
#
#   age_group gender  assembly_no category    weight
# 0     25-40   Male          211      Gen  0.346969
# 1     25-40   Male          189       BC  0.603419
# 2     25-40   Male          191      Gen  0.673762
# 3     25-40   Male          194      Gen  1.101298
# 4     18-25   Male          176       BC  0.333505

# %%
col1 = survey['collection_date'].value_counts()

# %%
col1
# Out:
# 2017-05-24    1479
# 2017-05-25     998
# 2017-05-28     761
# 2017-05-27     665
# 2017-05-29     620
# 2017-06-01     607
# 2017-05-26     598
# 2017-05-30     582
# 2017-05-31     557
# Name: collection_date, dtype: int64

# %%
col2 = survey[ survey['MLA_satisfaction'] == 'Fully Dissatisfied' ]['collection_date'].value_counts()

# %%
col2
# Out:
# 2017-05-24    887
# 2017-05-25    630
# 2017-05-28    462
# 2017-05-27    403
# 2017-06-01    385
# 2017-05-30    361
# 2017-05-26    353
# 2017-05-29    350
# 2017-05-31    321
# Name: collection_date, dtype: int64

# %%
df = pd.DataFrame({'Total Count' : col1 , 'Fully Dissatisfied' : col2})

# %%
df
# Out:
#             Total Count  Fully Dissatisfied  Proportion
# 2017-05-24         1479                 887    0.599730
# 2017-05-25          998                 630    0.631263
# 2017-05-26          598                 353    0.590301
# 2017-05-27          665                 403    0.606015
# 2017-05-28          761                 462    0.607096
# 2017-05-29          620                 350    0.564516
# 2017-05-30          582                 361    0.620275
# 2017-05-31          557                 321    0.576302
# 2017-06-01          607                 385    0.634267

# %%
df.index
# Out:
# DatetimeIndex(['2017-05-24', '2017-05-25', '2017-05-26', '2017-05-27',
#                '2017-05-28', '2017-05-29', '2017-05-30', '2017-05-31',
#                '2017-06-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
df['Proportion'] = df['Fully Dissatisfied']/df['Total Count']

# %%
df
# Out:
#             Total Count  Fully Dissatisfied  Proportion
# 2017-05-24         1479                 887    0.599730
# 2017-05-25          998                 630    0.631263
# 2017-05-26          598                 353    0.590301
# 2017-05-27          665                 403    0.606015
# 2017-05-28          761                 462    0.607096
# 2017-05-29          620                 350    0.564516
# 2017-05-30          582                 361    0.620275
# 2017-05-31          557                 321    0.576302
# 2017-06-01          607                 385    0.634267

# %%
from matplotlib import pyplot as plt

import seaborn as sns

# %%
fig, ax = plt.subplots( figsize = (15,7), dpi = 300)

sns.lineplot( x = df.index , y = df['Proportion'], ax = ax, lw = 5)
# Out:
# <AxesSubplot:ylabel='Proportion'>

# %% [markdown]
# # Question 9 - Create a pivot-table (or crosstab) with index as Past_Vote, Column as Vote_Now and cell values as the count of samples.
# Answer - survey.pivot_table(index = 'Past_Vote', columns = 'Vote_Now', values = 'response_id', aggfunc = 'count')

# %%
survey.head()
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1      2017-05-24       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2      2017-05-24       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3      2017-05-24       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4      2017-05-24       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 4            5      2017-05-24       Rural   Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction  age  \
# 0      BJP           BJP  Fully Dissatisfied  Fully Dissatisfied   26
# 1     RLSP         JD(U)  Somewhat Satisfied  Fully Dissatisfied   34
# 2   JAP(L)           BJP  Fully Dissatisfied  Somewhat Satisfied   25
# 3      RJD           RJD  Fully Dissatisfied  Somewhat Satisfied   36
# 4    JD(U)  Did not vote     Fully Satisfied     Fully Satisfied   22
#
#   age_group gender  assembly_no category    weight
# 0     25-40   Male          211      Gen  0.346969
# 1     25-40   Male          189       BC  0.603419
# 2     25-40   Male          191      Gen  0.673762
# 3     25-40   Male          194      Gen  1.101298
# 4     18-25   Male          176       BC  0.333505

# %%
survey.pivot_table(index = 'Past_Vote', columns = 'Vote_Now', values = 'response_id', aggfunc = 'count')
# Out:
# Vote_Now      AAP  AIMIM     BJP  BSP  HAM   INC  JAP(L)  JD(U)   LJP  \
# Past_Vote
# BJP           7.0    1.0  1630.0  3.0  5.0  42.0   101.0  110.0  44.0
# BSP           NaN    1.0     2.0  5.0  NaN   1.0     NaN    NaN   NaN
# Did not vote  8.0    5.0   231.0  2.0  1.0  22.0    41.0   69.0  10.0
# HAM           2.0    NaN    25.0  NaN  1.0   NaN     3.0    2.0   2.0
# INC           NaN    6.0     6.0  NaN  NaN  57.0    10.0    9.0   NaN
# JAP(L)        NaN    NaN     4.0  NaN  NaN   NaN    35.0    NaN   NaN
# JD(U)         6.0   10.0   254.0  2.0  2.0  45.0    72.0  279.0  29.0
# LJP           NaN    NaN    76.0  1.0  NaN   4.0     3.0    6.0   9.0
# Left Front    NaN    1.0     2.0  NaN  NaN   1.0     NaN    NaN   NaN
# NOTA          NaN    1.0    29.0  1.0  NaN   9.0     7.0    7.0   3.0
# Others        1.0    5.0    45.0  1.0  1.0   4.0     7.0    4.0   1.0
# RJD           3.0    7.0    46.0  NaN  1.0  31.0    31.0   39.0   4.0
# RLSP          NaN    NaN    17.0  NaN  NaN   NaN     3.0    NaN   NaN
# VIP           NaN    NaN     NaN  NaN  NaN   NaN     NaN    1.0   NaN
#
# Vote_Now      Left Front   NOTA  Others  Plurals    RJD  RJJP  RLSP  \
# Past_Vote
# BJP                 13.0  194.0    32.0     87.0  370.0  88.0  24.0
# BSP                  NaN    NaN     NaN      NaN    NaN   NaN   NaN
# Did not vote        16.0   83.0    11.0     51.0  195.0  20.0   3.0
# HAM                  NaN    4.0     NaN      NaN    6.0   4.0   NaN
# INC                  3.0    6.0     3.0      3.0  100.0   1.0   2.0
# JAP(L)               NaN    NaN     1.0      NaN    2.0   NaN   NaN
# JD(U)                9.0   90.0    18.0     43.0  435.0  13.0  25.0
# LJP                  2.0    3.0     NaN      2.0   17.0   1.0   NaN
# Left Front          18.0    1.0     1.0      NaN    4.0   NaN   1.0
# NOTA                 5.0   46.0     7.0     11.0   27.0   5.0   4.0
# Others               4.0   10.0     6.0      8.0   21.0   7.0   1.0
# RJD                  9.0   18.0     8.0     10.0  811.0   1.0  10.0
# RLSP                 NaN    3.0     NaN      2.0    8.0   2.0  12.0
# VIP                  NaN    NaN     NaN      NaN    NaN   NaN   NaN
#
# Vote_Now      Undecided   VIP
# Past_Vote
# BJP                62.0  10.0
# BSP                 NaN   NaN
# Did not vote       31.0   5.0
# HAM                 1.0   NaN
# INC                 7.0   NaN
# JAP(L)              NaN   NaN
# JD(U)              36.0   6.0
# LJP                 1.0   NaN
# Left Front          NaN   1.0
# NOTA                5.0   NaN
# Others              6.0   NaN
# RJD                14.0   4.0
# RLSP                1.0   1.0
# VIP                 NaN   1.0

# %% [markdown]
# # Question 10 - Repeat the above question with the cell values as the sum of “weight”.

# %%
survey.pivot_table(index = 'Past_Vote', columns = 'Vote_Now', values = 'weight', aggfunc = 'sum')
# Out:
# Vote_Now            AAP      AIMIM          BJP        BSP        HAM  \
# Past_Vote
# BJP            4.807335   0.349996  1049.344112   0.452551  10.171283
# BSP                 NaN   1.654731     5.174487  32.010277        NaN
# Did not vote   8.865896   5.379527   114.203906   3.329611   2.497170
# HAM            0.312607        NaN    25.348884        NaN   1.648856
# INC                 NaN  11.105958     1.642875        NaN        NaN
# JAP(L)              NaN        NaN     6.512846        NaN        NaN
# JD(U)         12.457216  29.198610   156.243100  11.005903   2.639574
# LJP                 NaN        NaN    85.010450   2.481377        NaN
# Left Front          NaN   2.298223     0.209586        NaN        NaN
# NOTA                NaN   1.061204    12.685435   0.051485        NaN
# Others        13.661335  21.212705    34.866218   0.684568   1.505864
# RJD            5.515847  24.149369    32.285093        NaN   0.960400
# RLSP                NaN        NaN    23.376575        NaN        NaN
# VIP                 NaN        NaN          NaN        NaN        NaN
#
# Vote_Now             INC      JAP(L)       JD(U)        LJP  Left Front  \
# Past_Vote
# BJP            50.055502   63.832368   68.029581  45.716215    7.537394
# BSP             2.298223         NaN         NaN        NaN         NaN
# Did not vote   27.791290   26.359190   58.983458  11.801813   13.050113
# HAM                  NaN    0.712161    1.006719   2.496424         NaN
# INC           161.742302   18.942597   11.077323        NaN    6.268726
# JAP(L)               NaN   57.876224         NaN        NaN         NaN
# JD(U)          91.806262  106.217216  498.796862  33.148113   11.765603
# LJP            21.613385    7.375946   11.382812  26.868529    1.712452
# Left Front      2.291368         NaN         NaN        NaN   44.280864
# NOTA            3.844332    8.645440   12.132362   1.353138    2.863587
# Others          1.389539    5.333891    5.101976   2.481377    4.017150
# RJD            67.072640   28.661774   55.385673   9.226178   35.399702
# RLSP                 NaN    3.269255         NaN        NaN         NaN
# VIP                  NaN         NaN    0.333505        NaN         NaN
#
# Vote_Now            NOTA     Others    Plurals          RJD       RJJP  \
# Past_Vote
# BJP           114.913686   8.790137  50.016163   250.948101  16.047570
# BSP                  NaN        NaN        NaN          NaN        NaN
# Did not vote   44.725179   7.289933  25.319524   173.882525   4.349832
# HAM             0.928984        NaN        NaN     7.713008   1.903148
# INC             5.999014   1.552038   1.588527   195.020050   5.340403
# JAP(L)               NaN   3.195682        NaN     2.164824        NaN
# JD(U)          61.109706  29.196072  45.175289   657.155514   4.015909
# LJP             0.813171        NaN   1.927965    30.737989   0.478933
# Left Front      0.201455   8.309203        NaN     6.740281        NaN
# NOTA           35.310377  13.594657   3.676105    20.552066   1.116006
# Others          9.419087   8.236678   2.715087    38.194805   1.754671
# RJD            25.113668  14.999222  14.179660  1016.975742   0.085758
# RLSP            1.097574        NaN   0.499403    14.951502   1.955662
# VIP                  NaN        NaN        NaN          NaN        NaN
#
# Vote_Now           RLSP  Undecided        VIP
# Past_Vote
# BJP           18.715113  41.286954  18.691691
# BSP                 NaN        NaN        NaN
# Did not vote   5.041587  22.015457  10.696552
# HAM                 NaN   0.039564        NaN
# INC            1.140299   8.558475        NaN
# JAP(L)              NaN        NaN        NaN
# JD(U)         44.376194  58.137833  20.675288
# LJP                 NaN   1.709409        NaN
# Left Front     0.877960        NaN   3.020887
# NOTA           4.502676   1.570309        NaN
# Others         3.800565   2.504778        NaN
# RJD           10.752145  21.523115  13.161145
# RLSP          23.505807   3.524302   8.258391
# VIP                 NaN        NaN   0.372959

# %% [markdown]
# # Question 11 - Create a dataframe by performing a group by over age_group and calculate the count of total samples under each age_group.

# %%
survey.head()
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1      2017-05-24       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2      2017-05-24       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3      2017-05-24       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4      2017-05-24       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 4            5      2017-05-24       Rural   Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction  age  \
# 0      BJP           BJP  Fully Dissatisfied  Fully Dissatisfied   26
# 1     RLSP         JD(U)  Somewhat Satisfied  Fully Dissatisfied   34
# 2   JAP(L)           BJP  Fully Dissatisfied  Somewhat Satisfied   25
# 3      RJD           RJD  Fully Dissatisfied  Somewhat Satisfied   36
# 4    JD(U)  Did not vote     Fully Satisfied     Fully Satisfied   22
#
#   age_group gender  assembly_no category    weight
# 0     25-40   Male          211      Gen  0.346969
# 1     25-40   Male          189       BC  0.603419
# 2     25-40   Male          191      Gen  0.673762
# 3     25-40   Male          194      Gen  1.101298
# 4     18-25   Male          176       BC  0.333505

# %%
dfnew = survey.groupby('age_group')['response_id'].count().reset_index()

# %%
dfnew
# Out:
#   age_group  response_id
# 0     18-25         2094
# 1     25-40         3844
# 2     40-55          801
# 3       55+          128

# %% [markdown]
# # Question 12 - Create a dataframe by performing a group by over age_group and finding the count of total samples for each age_group that opted for the JD(U) party in Vote_Now.

# %%
df_JDU = survey[survey['Vote_Now'] == 'JD(U)'].groupby('age_group')['response_id'].count().reset_index()

# %%
df_JDU
# Out:
#   age_group  response_id
# 0     18-25          181
# 1     25-40          264
# 2     40-55           68
# 3       55+           13

# %% [markdown]
# # Question 13 - Join/Merge the two dataframes from questions 12 and 11 with the common column as age_group.

# %%
joined_df = pd.merge(dfnew, df_JDU, on = 'age_group' )

# %%
joined_df
# Out:
#   age_group  response_id_x  response_id_y
# 0     18-25           2094            181
# 1     25-40           3844            264
# 2     40-55            801             68
# 3       55+            128             13
